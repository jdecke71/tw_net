# %% [markdown]
# ## Analysis
# ---
#
# #### Import Scripts

# %%
# %run -i '../scripts/tw_net_cleaning.py'

# %%
# %run -i '../scripts/tw_net_analysis.py'

# %%
# %run -i '../scripts/tw_net_extraction.py'

# %% [markdown]
# #### Load & Clean Tweets

# %%
'''
Enter days/sets/calls combination to select 
one or more sets of tweets to be returned as dataframe.

'''
days = [18,19,20,21]
sets = [1,2,3,4,5,6]
calls = [1,2,3,4,5]
tweets_per_call = 150

df = TweetsToDataframe(days,sets,calls,tweets_per_call,useWeights=True)

df.head()
# Out:
# ../scripts/tw_net_analysis.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   def QueryValues(attr,day,set_n,call=0):
# ../scripts/tw_net_analysis.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   day_num = day
# ../scripts/tw_net_analysis.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   set_name = set_n
# ../scripts/tw_net_analysis.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   call_num = call
# ../scripts/tw_net_analysis.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   filename = GetFileName(day_num,set_name,call_num)
#                 id_str                                               text  \
# 0  1097473283946172417                                   @NetflixFR A Moi
# 1  1097473425747132416  @Dylan_Derpy @TheRogueEnergy This is what I th...
# 2  1097473465668550656  @realDonaldTrump Nice distraction from manafor...
# 3  1097473503736066048  But his supporters said It’s only the Daily Ma...
# 4  1097473510811803648                               4 more on this video
#
#   created_hr created_dotw                    calltime day set call  \
# 0          7          Mon  2019-02-18 07:52:11.164523  18   1    1
# 1          7          Mon  2019-02-18 07:52:11.164523  18   1    1
# 2          7          Mon  2019-02-18 07:52:11.164523  18   1    1
# 3          7          Mon  2019-02-18 07:52:11.164523  18   1    1
# 4          7          Mon  2019-02-18 07:52:11.164523  18   1    1
#
#    favorite_count  retweet_count        ...        profile_background_color  \
# 0               0              0        ...                          000000
# 1               0              0        ...                          000000
# 2               0              0        ...                          C6E2EE
# 3               0              0        ...                          C0DEED
# 4               0              0        ...                          BADFCD
#
#   profile_text_color user_screen_name  statuses_count verified num_tags  \
# 0             000000    nicolas_dulac              58    False        0
# 1             000000  GHILLIEMCGEE282             504    False        0
# 2             663B12        TodfromPa           45833    False        0
# 3             333333       erlyonurse            1038    False        0
# 4             0C3E53        KurlyKole           38712    False        0
#
#   num_media num_symbols num_urls num_user_mentions
# 0         0           0        0                 1
# 1         0           0        0                 2
# 2         0           0        1                 1
# 3         0           0        1                 0
# 4         0           0        0                 0
#
# [5 rows x 39 columns]

# %%
df.describe()
# Out:
#        favorite_count  retweet_count  influence_score    user_since  \
# count    28245.000000   28245.000000     28245.000000  28245.000000
# mean         1.257745       0.219685        57.239888      5.435404
# std          8.292870       2.015008       211.008287      3.125459
# min          0.000000       0.000000         0.000000      0.000000
# 25%          0.000000       0.000000         4.400000      3.000000
# 50%          0.000000       0.000000        13.100000      6.000000
# 75%          1.000000       0.000000        37.825000      8.000000
# max        469.000000     145.000000      3947.000000     12.000000
#
#        favorites_counts  followers_count  friends_count  listed_count  \
# count      28245.000000     28245.000000   28245.000000  28245.000000
# mean       20650.295557      2177.477288    1521.484865     30.584280
# std        40597.276387      8211.722059    3620.172550    106.995038
# min            0.000000         0.000000       0.000000      0.000000
# 25%         1374.000000       158.000000     248.000000      1.000000
# 50%         6076.000000       457.000000     579.000000      4.000000
# 75%        19721.000000      1422.000000    1454.000000     19.000000
# max       468557.000000    154189.000000   51921.000000   2332.000000
#
#        statuses_count      num_tags     num_media   num_symbols      num_urls  \
# count    28245.000000  28245.000000  28245.000000  28245.000000  28245.000000
# mean     28210.544061      0.195256      0.094778      0.000177      0.412781
# std      50862.893529      0.741141      0.292913      0.013304      0.501393
# min          1.000000      0.000000      0.000000      0.000000      0.000000
# 25%       2269.000000      0.000000      0.000000      0.000000      0.000000
# 50%       9335.000000      0.000000      0.000000      0.000000      0.000000
# 75%      27268.000000      0.000000      0.000000      0.000000      1.000000
# max     371459.000000      9.000000      1.000000      1.000000      2.000000
#
#        num_user_mentions
# count       28245.000000
# mean            1.075482
# std             1.542706
# min             0.000000
# 25%             0.000000
# 50%             1.000000
# 75%             1.000000
# max            10.000000

# %%
'''
Distribution of influence scores
'''
ax = sns.distplot(df['influence_score'],kde=False)
# Out:
# /Users/jessedecker/miniconda3/envs/gis/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
outliers = df['influence_score'].mean()+ df['influence_score'].std()*3.5

df = df[df['influence_score'] < outliers]

# %%
ax = sns.distplot(df['influence_score'],kde=False)

# %% [markdown]
# #### Preview Feature Set

# %%
'''
Wrap all but text. Leave identifiers and text to check.
''' 
preview_df = PreviewFeatureSet(df,isRandom=False)
preview_df.head()
# Out:
#                   tweet_id                                               text  \
# 14969  1098663746740862977  “Roughly 50% of consumers have chosen to buy a...
# 14680  1098629495463071744      @DrJavariaPHTF Hahaha :D \nGood one indeed !!
# 14579  1098630384231825408                                @buchchii True 100%
# 16129  1098698108412878848            @egg_free_cake I don't know about it :|
# 9823   1098233971404652545  @dawnchats I need to book this for my kids!!! ...
#
#       created_hr set  favorite_count  retweet_count  influence_score  \
# 14969         14   4               1              0         9683.500
# 14680         12   3               1              1         3254.350
# 14579         12   3               1              0         3253.750
# 16129         16   5               0              0         3253.700
# 9823           9   2               2              0         2881.225
#
#                                         user_description  user_since  \
# 14969  CEO @ChopDawgStudios for 🔟 years. Founded at 1...           9
# 14680  Very Passionate Sincere Activist Proud Pakista...           5
# 14579  Very Passionate Sincere Activist Proud Pakista...           5
# 16129  Very Passionate Sincere Activist Proud Pakista...           5
# 9823   Classy Mommy Founder\nTravel, Family, Style \n...          10
#
#        favorites_counts  ...   num_tags  num_media  num_symbols  num_urls  \
# 14969              8073  ...          0          0            0         1
# 14680            463814  ...          0          0            0         0
# 14579            463814  ...          0          0            0         0
# 16129            463803  ...          0          0            0         0
# 9823               1878  ...          2          0            0         0
#
#        num_user_mentions  influence_interval  isVerified  isRetweeted  \
# 14969                  0                   1           0            0
# 14680                  1                   4           0            1
# 14579                  1                   3           0            0
# 16129                  1                   4           0            0
# 9823                   1                   4           0            0
#
#        isReply  dotw
# 14969        0     5
# 14680        1     5
# 14579        1     5
# 16129        1     5
# 9823         1     4
#
# [5 rows x 24 columns]

# %%
ax = sns.countplot(x="influence_interval", data=preview_df)

# %% [markdown]
# #### Extract and Save Feature Set

# %%
'''
Wrap text, remove identifiers/text, output ready for ml.
This takes forever.
''' 
featureSet = GetFeatureSet(preview_df)
featureSet.head()
# Out:
#       created_hr set  favorite_count  retweet_count  influence_score  \
# 14969         14   4               1              0         9683.500
# 14680         12   3               1              1         3254.350
# 14579         12   3               1              0         3253.750
# 16129         16   5               0              0         3253.700
# 9823           9   2               2              0         2881.225
#
#        user_since  followers_count  listed_count  num_tags  num_media  \
# 14969           9           379714          2538         0          0
# 14680           5           129643           165         0          0
# 14579           5           129643           165         0          0
# 16129           5           129653           165         0          0
# 9823           10           109636          1863         2          0
#
#        num_symbols  num_urls  num_user_mentions  influence_interval  \
# 14969            0         1                  0                   1
# 14680            0         0                  1                   4
# 14579            0         0                  1                   3
# 16129            0         0                  1                   4
# 9823             0         0                  1                   4
#
#        isVerified  isRetweeted  isReply  dotw
# 14969           0            0        0     5
# 14680           0            1        1     5
# 14579           0            0        1     5
# 16129           0            0        1     5
# 9823            0            0        1     4

# %%
featureSet.columns
# Out:
# Index(['created_hr', 'set', 'favorite_count', 'retweet_count',
#        'influence_score', 'user_since', 'followers_count', 'listed_count',
#        'num_tags', 'num_media', 'num_symbols', 'num_urls', 'num_user_mentions',
#        'influence_interval', 'isVerified', 'isRetweeted', 'isReply', 'dotw'],
#       dtype='object')

# %%
file_io.WriteCSV(df,'wk2_weighted_notext')

# %%
g = sns.pairplot(featureSet,vars=["influence_score",'favorite_count','retweet_count','listed_count','followers_count'])

# %%
h = sns.pairplot(featureSet,vars=[ "influence_score",'set'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/Mercyhurst/CIS_572/final/tw_net/scripts/tw_net_analysis.py in <module>
# ----> 1 h = sns.pairplot(featureSet,vars=[ "influence_score",'set'])
#
# ~/miniconda3/envs/gis/lib/python3.6/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2105     if grid.square_grid:
#    2106         if diag_kind == "hist":
# -> 2107             grid.map_diag(plt.hist, **diag_kws)
#    2108         elif diag_kind == "kde":
#    2109             diag_kws.setdefault("shade", True)
#
# ~/miniconda3/envs/gis/lib/python3.6/site-packages/seaborn/axisgrid.py in map_diag(self, func, **kwargs)
#    1397                     color = fixed_color
#    1398
# -> 1399                 func(data_k, label=label_k, color=color, **kwargs)
#    1400
#    1401             self._clean_axis(ax)
#
# ~/miniconda3/envs/gis/lib/python3.6/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2659         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2660         color=color, label=label, stacked=stacked, normed=normed,
# -> 2661         **({"data": data} if data is not None else {}), **kwargs)
#    2662
#    2663
#
# ~/miniconda3/envs/gis/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/miniconda3/envs/gis/lib/python3.6/site-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, **kwargs)
#    6563                     "color kwarg must have one color per data set. %d data "
#    6564                     "sets and %d colors were provided" % (nx, len(color)))
# -> 6565                 raise ValueError(error_message)
#    6566
#    6567         # If bins are not specified either explicitly or via range,
#
# ValueError: color kwarg must have one color per data set. 2806 data sets and 1 colors were provided
