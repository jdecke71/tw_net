# %%
# %run -i '../scripts/tw_net_collection.py'

# %%
# %run -i '../scripts/tw_net_cleaning.py'

# %%
# %run -i '../scripts/tw_net_analysis.py'

# %%
# %run -i '../scripts/tw_net_extraction.py'

# %%
# %run -i '../scripts/tw_net_networking.py'

# %%
df = file_io.ReadCSV('erie_tweets_c1')
# Out:
# filename: ../data/models/erie_tweets_c1.csv

# %%
df = df.sort_values(by=['influence_score'],ascending=False)

# %%
df.head()
# Out:
#                    id_str                                               text  \
# 5351  1096922040559386626  Your @MarshaMarsh Starters of the Game:\n\nSel...
# 6077  1097248979346165760  That'll do it for the First Period.  We trail ...
# 5978  1097247218724192257  Evan Bouchard scores and its 4-0 London.\n\n5:...
# 6065  1097248723242020865  Gerard Keane is called for Holding and we will...
# 6239  1097282580183961600  Otters Find Scoring Too Late, Fall 8-5 to Lond...
#
#       created_hr created_dotw                    calltime  day  set  call  \
# 5351          18          Sat  2019-02-16 19:00:31.011348   16    6     1
# 6077          16          Sun  2019-02-17 16:42:43.865082   17    5     1
# 5978          16          Sun  2019-02-17 16:42:43.865082   17    5     1
# 6065          16          Sun  2019-02-17 16:42:43.865082   17    5     1
# 6239          18          Sun  2019-02-17 18:53:59.653048   17    6     1
#
#       favorite_count  retweet_count        ...          \
# 5351               0              0        ...
# 6077               0              0        ...
# 5978               0              0        ...
# 6065               0              0        ...
# 6239               0              0        ...
#
#      profile_background_color profile_text_color user_screen_name  \
# 5351                   A50909             EDC40C       ErieOtters
# 6077                   A50909             EDC40C       ErieOtters
# 5978                   A50909             EDC40C       ErieOtters
# 6065                   A50909             EDC40C       ErieOtters
# 6239                   A50909             EDC40C       ErieOtters
#
#       statuses_count  verified  num_tags num_media  num_symbols  num_urls  \
# 5351           30832      True         0         0            0         0
# 6077           30867      True         0         0            0         0
# 5978           30865      True         0         0            0         0
# 6065           30866      True         0         0            0         0
# 6239           30894      True         0         1            0         1
#
#       num_user_mentions
# 5351                  1
# 6077                  0
# 5978                  0
# 6065                  1
# 6239                  0
#
# [5 rows x 39 columns]

# %%
df.columns
# Out:
# Index(['id_str', 'text', 'created_hr', 'created_dotw', 'calltime', 'day',
#        'set', 'call', 'favorite_count', 'retweet_count', 'place_names',
#        'place_ids', 'sources', 'influence_score', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id_str', 'lang', 'is_quote_status', 'retweeted',
#        'truncated', 'user_id_str', 'user_name', 'user_description',
#        'user_location', 'user_since', 'favorites_counts', 'followers_count',
#        'friends_count', 'listed_count', 'profile_background_color',
#        'profile_text_color', 'user_screen_name', 'statuses_count', 'verified',
#        'num_tags', 'num_media', 'num_symbols', 'num_urls',
#        'num_user_mentions'],
#       dtype='object')

# %%
df.describe()
# Out:
#              id_str  created_hr         day         set   call  \
# count  3.740000e+02  374.000000  374.000000  374.000000  374.0
# mean   1.096048e+18   13.347594   13.799465    3.802139    1.0
# std    7.067968e+14    3.660825    1.929008    1.649891    0.0
# min    1.094937e+18    7.000000   11.000000    1.000000    1.0
# 25%    1.095436e+18    9.000000   12.000000    2.000000    1.0
# 50%    1.096060e+18   14.000000   14.000000    4.000000    1.0
# 75%    1.096559e+18   16.000000   15.000000    5.000000    1.0
# max    1.097283e+18   19.000000   17.000000    6.000000    1.0
#
#        favorite_count  retweet_count  influence_score  \
# count           374.0          374.0       374.000000
# mean              0.0            0.0        40.289439
# std               0.0            0.0       130.937042
# min               0.0            0.0         0.025000
# 25%               0.0            0.0         7.375000
# 50%               0.0            0.0        12.700000
# 75%               0.0            0.0        28.543750
# max               0.0            0.0      1101.525000
#
#        in_reply_to_status_id_str  in_reply_to_user_id_str        ...          \
# count               1.260000e+02             1.410000e+02        ...
# mean                1.094941e+18             2.212839e+17        ...
# std                 1.179755e+16             3.910561e+17        ...
# min                 9.638183e+17             2.461030e+05        ...
# 25%                 1.095400e+18             2.329013e+08        ...
# 50%                 1.095816e+18             6.299049e+08        ...
# 75%                 1.096556e+18             4.870859e+09        ...
# max                 1.097279e+18             1.085592e+18        ...
#
#        favorites_counts  followers_count  friends_count  listed_count  \
# count        374.000000       374.000000     374.000000    374.000000
# mean       25881.462567      1534.965241     997.449198     25.537433
# std        42347.821997      5118.385974    1782.395086     59.663960
# min            0.000000         1.000000      27.000000      0.000000
# 25%          637.000000       290.000000     302.000000      1.000000
# 50%         8553.000000       449.500000     475.000000      8.500000
# 75%        30044.000000      1049.750000    1137.250000     19.000000
# max       188071.000000     42993.000000   20274.000000    695.000000
#
#        statuses_count    num_tags   num_media  num_symbols    num_urls  \
# count      374.000000  374.000000  374.000000        374.0  374.000000
# mean     32909.109626    0.117647    0.061497          0.0    0.267380
# std      45808.306468    0.453829    0.240562          0.0    0.443185
# min          1.000000    0.000000    0.000000          0.0    0.000000
# 25%       4130.750000    0.000000    0.000000          0.0    0.000000
# 50%      18307.500000    0.000000    0.000000          0.0    0.000000
# 75%      40388.750000    0.000000    0.000000          0.0    1.000000
# max     216048.000000    4.000000    1.000000          0.0    1.000000
#
#        num_user_mentions
# count         374.000000
# mean            0.708556
# std             1.195650
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%             1.000000
# max             8.000000
#
# [8 rows x 22 columns]

# %%
ax = sns.distplot(df['influence_score'],kde=False)
# Out:
# /Users/jessedecker/miniconda3/envs/gis/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
outliers = df['influence_score'].mean()+ df['influence_score'].std()*3.5

df = df[df['influence_score'] < outliers]

# df = df[df['influence_score'] >= 12.675]

# %%
users = list(df['user_id_str'].unique())
# len(users)

# %%
users[:17]
# Out:
# [65641854,
#  201136410,
#  318061556,
#  807413918586933248,
#  176519163,
#  1872134220,
#  146879662,
#  2409232175,
#  3293178390,
#  347321459,
#  15648708,
#  590526622,
#  351097318,
#  1512551,
#  259872649,
#  1615762506,
#  394394376]

# %%
user = '1615762506'
# GetUser(user)
# GetFollowers(user)
# GetFriends(user)

# %%
'''
Query user, follower, and friend info. Save to files.
Hitting limit on users with many followers. Run individually.
'''
user = '347321459'
# GetUser(user)
# GetFollowers(user)
# GetFriends(user)

# %%
'''
Use subsets of most active users to build graph.
'''
active_users = users[:15]

# G.clear()
G = LoadGraph(active_users)

# %%
PrintSummaryTwo(G)
# Out:
# Graph Density
# --------------------------------------------
# Number of Nodes :	 125
# Number of Edges :	 164
# Graph Density :	 	 0.010580645161290323
#
#
# Score Comparison
# Name 	 	 	 Score 	 	 DC 	 BC 	 CC
# --------------------------------------------
# ETNreisenweber 	 	 238.07 	 	 0.20 	 0.06 	 0.19
# lindapezzino 	 	 193.68 	 	 0.00 	 0.00 	 0.00
# MissMelissaST 	 	 122.70 	 	 0.00 	 0.00 	 0.00
# PrepVilla 	 	 115.25 	 	 0.20 	 0.05 	 0.22
# HurstMensHockey 	 	 106.68 	 	 0.13 	 0.03 	 0.15
# BenFrankBrian 	 	 95.90 	 	 0.21 	 0.02 	 0.11
# jasonwooddd 	 	 75.50 	 	 0.05 	 0.01 	 0.08
# JamesIsaak2 	 	 70.80 	 	 0.00 	 0.00 	 0.00
# PEPHockey 	 	 70.53 	 	 0.00 	 0.00 	 0.00
# bbrannan 	 	 68.25 	 	 0.01 	 0.00 	 0.00
# kennyrob24 	 	 51.95 	 	 0.05 	 0.00 	 0.02
# iacas 	 	 49.80 	 	 0.02 	 0.00 	 0.01
# grant_kru 	 	 49.45 	 	 0.11 	 0.02 	 0.15
# /Users/jessedecker/miniconda3/envs/gis/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):
